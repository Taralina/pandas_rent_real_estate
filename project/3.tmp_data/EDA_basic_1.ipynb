# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## Подготовительная часть задания

# %%
# Загрузить ДФ
path = '/Users/vladislavkravchenko/Desktop/WORK_IT/1.Elbrus_Bootcamp/2.Phase0/4.Thursday/rent_real_estate/_data.csv'
df = pd.read_csv(path)
# df = pd.read_csv('_data.csv')
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#        Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0               0       271271157                 4  Квартира
# 1               1       271634126                 4  Квартира
# 2               2       271173086   4, Оба варианта  Квартира
# 3               3       272197456   4, Оба варианта  Квартира
# 4               4       273614615                 2  Квартира
# ...           ...             ...               ...       ...
# 23363       23363       215565511               NaN  Квартира
# 23364       23364       274654844                 1  Квартира
# 23365       23365       268679909   2, Оба варианта  Квартира
# 23366       23366       274807525                 2  Квартира
# 23367       23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# 4       м. Арбатская (7 мин пешком)
# ...                             ...
# 23363    м. Говорово (8 мин пешком)
# 23364    м. Солнцево (7 мин пешком)
# 23365    м. Солнцево (6 мин пешком)
# 23366   м. Солнцево (11 мин пешком)
# 23367   м. Говорово (10 мин пешком)
#
#                                                    Адрес      Площадь, м2  \
# 0                          Москва, улица Новый Арбат, 27       200.0/20.0
# 1                          Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2                          Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3                       Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4                          Москва, улица Новый Арбат, 15    58.0/38.0/5.0
# ...                                                  ...              ...
# 23363  Москва, Боровское шоссе, 2к7, ш. Боровское (3 ...    35.0/16.4/8.0
# 23364  Москва, Производственная улица, 8к1, ш. Боровс...   38.7/16.5/11.0
# 23365                       Москва, Боровский проезд, 11             43.1
# 23366  Москва, улица Богданова, 6к1, ш. Боровское (3 ...        52.5/10.0
# 23367  Москва, улица Богданова, 2к1, ш. Боровское (3 ...   90.0/48.2/15.5
#
#                              Дом   Парковка  \
# 0               5/16, Монолитный  подземная
# 1      5/16, Монолитно-кирпичный  подземная
# 2                           5/16  подземная
# 3                            5/6  подземная
# 4               12/26, Панельный        NaN
# ...                          ...        ...
# 23363                      10/14        NaN
# 23364           5/18, Монолитный        NaN
# 23365             5/5, Кирпичный        NaN
# 23366           8/23, Монолитный   наземная
# 23367            6/23, Панельный        NaN
#
#                                                     Цена  \
# 0      500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 1      500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 2      500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 3      400000.0 руб./ За месяц, Залог - 400000 руб., ...
# 4      225000.0 руб./ За месяц, Залог - 225000 руб., ...
# ...                                                  ...
# 23363  42000.0 руб./ За месяц, Залог - 42000 руб., Ко...
# 23364  45000.0 руб./ За месяц, Залог - 45000 руб., Ко...
# 23365  50000.0 руб./ За месяц, Залог - 50000 руб., Ко...
# 23366  55000.0 руб./ За месяц, Залог - 50000 руб., Ко...
# 23367  57000.0 руб./ За месяц, Залог - 60000 руб., Ко...
#
#                          Телефоны  \
# 0                    +79166369231
# 1                    +79850608590
# 2      +79672086536, +79099269384
# 3      +79660342340, +79099269384
# 4                    +79852432860
# ...                           ...
# 23363                +79154383401
# 23364                +79151173402
# 23365                +79653825192
# 23366                +79660611965
# 23367                +79623641533
#
#                                                 Описание         Ремонт  \
# 0      Без комиссии для нанимателя! Бонус коллегам 12...   Дизайнерский
# 1      Лот 93107. Елена Анисимова.\n\nБонус агенту 50...   Дизайнерский
# 2      ID 36380:  Шикарная 4-х км. квартира в ЖК "Нов...     Евроремонт
# 3      ID 31618:  Эксклюзивное предложение. Современн...     Евроремонт
# 4      Лот 111542. Татьяна Лучкина.\n\nБонус агенту 5...     Евроремонт
# ...                                                  ...            ...
# 23363  Сдаётся светлая теплая квартира (студия) с бал...     Евроремонт
# 23364  Сдам однокомнатную квартиру на длительный срок...     Евроремонт
# 23365  Рассматриваются квартиранты только славяне и т...   Дизайнерский
# 23366  Двухкомнатная уютная квартира с видом во внутр...     Евроремонт
# 23367  Сдается просторная двухкомнатная квартира ВПЕР...  Косметический
#
#       Площадь комнат, м2      Балкон             Окна  \
# 0                    NaN         NaN              NaN
# 1            25 25 20 25         NaN  На улицу и двор
# 2                    NaN         NaN  На улицу и двор
# 3            14-42-20-19         NaN  На улицу и двор
# 4                  20 18         NaN  На улицу и двор
# ...                  ...         ...              ...
# 23363                NaN  Балкон (1)              NaN
# 23364                NaN  Лоджия (1)          Во двор
# 23365                NaN  Балкон (1)  На улицу и двор
# 23366                NaN  Лоджия (1)          Во двор
# 23367     26,2+15,5-22,0  Лоджия (1)          Во двор
#
#                                Санузел           Можно с детьми/животными  \
# 0                                  NaN  Можно с детьми, Можно с животными
# 1      Совмещенный (2), Раздельный (1)                     Можно с детьми
# 2                      Совмещенный (3)                     Можно с детьми
# 3                      Совмещенный (3)                  Можно с животными
# 4                      Совмещенный (2)                                NaN
# ...                                ...                                ...
# 23363                  Совмещенный (1)                                NaN
# 23364                  Совмещенный (1)                                NaN
# 23365                  Совмещенный (1)                     Можно с детьми
# 23366  Совмещенный (1), Раздельный (1)                                NaN
# 23367                   Раздельный (1)  Можно с детьми, Можно с животными
#
#                                            Дополнительно        Название ЖК  \
# 0      Мебель в комнатах, Мебель на кухне, Ванна, Душ...  Новый Арбат, 2010
# 1      Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 2      Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 3      Мебель в комнатах, Мебель на кухне, Ванна, Душ...                NaN
# 4      Мебель в комнатах, Мебель на кухне, Ванна, Душ...           The Book
# ...                                                  ...                ...
# 23363  Мебель в комнатах, Мебель на кухне, Ванна, Сти...      Мещерский лес
# 23364  Мебель в комнатах, Мебель на кухне, Ванна, Сти...               Лучи
# 23365  Мебель на кухне, Душевая кабина, Стиральная ма...                NaN
# 23366  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                NaN
# 23367  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                NaN
#
#       Серия дома  Высота потолков, м                Лифт Мусоропровод  \
# 0            NaN                3.00  Пасс (4), Груз (1)           Да
# 1            NaN                3.50  Пасс (1), Груз (1)          Нет
# 2            NaN                3.20            Пасс (1)          NaN
# 3            NaN                3.20            Пасс (1)          NaN
# 4            NaN                3.90  Пасс (1), Груз (1)           Да
# ...          ...                 ...                 ...          ...
# 23363        NaN                 NaN  Пасс (1), Груз (1)          NaN
# 23364        NaN                 NaN  Пасс (1), Груз (1)          NaN
# 23365        NaN                 NaN                 NaN          NaN
# 23366        NaN                2.65            Пасс (3)           Да
# 23367        NaN                 NaN            Пасс (3)           Да
#
#                           Ссылка на объявление
# 0      https://www.cian.ru/rent/flat/271271157
# 1      https://www.cian.ru/rent/flat/271634126
# 2      https://www.cian.ru/rent/flat/271173086
# 3      https://www.cian.ru/rent/flat/272197456
# 4      https://www.cian.ru/rent/flat/273614615
# ...                                        ...
# 23363  https://www.cian.ru/rent/flat/215565511
# 23364  https://www.cian.ru/rent/flat/274654844
# 23365  https://www.cian.ru/rent/flat/268679909
# 23366  https://www.cian.ru/rent/flat/274807525
# 23367  https://www.cian.ru/rent/flat/274672243
#
# [23368 rows x 25 columns]

# %%
# Выбор рабочих колонок, анализ которых позволяет провести графическую аналитику
df.rename(columns={'ID  объявления': 'ID объявления'}, inplace=True)
wdf = df[['Unnamed: 0',
    'ID объявления',  
   'Количество комнат', 
   'Метро', 
   'Площадь, м2', 
   'Дом', 
   'Парковка', 
   'Цена', 
   'Ремонт', 
   'Балкон', 
   'Окна', 
   'Санузел', 
   'Можно с детьми/животными',  
   'Высота потолков, м', 
   'Лифт', 
   'Мусоропровод']].copy()

# %%
# Замена нулевых значений
wdf.fillna(0, inplace=True)
wdf.isnull().sum()
# Out:
# Unnamed: 0                  0
# ID объявления               0
# Количество комнат           0
# Метро                       0
# Площадь, м2                 0
# Дом                         0
# Парковка                    0
# Цена                        0
# Ремонт                      0
# Балкон                      0
# Окна                        0
# Санузел                     0
# Можно с детьми/животными    0
# Высота потолков, м          0
# Лифт                        0
# Мусоропровод                0
# dtype: int64

# %%
# Шэйп ДФ для сверки результатов
wdf.shape
# Out:
# (23368, 16)

# %% [markdown]
# ## Основная часть задания

# %% [markdown]
# ### Колонка: Количество комнат.
# Задача: привести к типу int()

# %%
# Сплит по знаку запятой и взять только числа.
wdf = wdf.copy()
wdf['Количество комнат'] = wdf['Количество комнат'].apply(lambda x: int(x.split(',')[0]) if type(x) != int else int(x))

# %%
wdf['Количество комнат'].value_counts()
# Out:
# Количество комнат
# 2    8466
# 1    7931
# 3    4262
# 4    1163
# 0    1041
# 5     367
# 6     138
# Name: count, dtype: int64

# %%
# Проверка, что все значения численные
all(wdf['Количество комнат'].to_list()) == int()
# Out:
# True

# %% [markdown]
# ### Колонка: Метро.
# Задача: оставить только название станции

# %%
wdf['Метро'] = wdf['Метро'].apply(lambda x: x.split() if type(x) == str else x)
wdf['Метро'] = wdf['Метро'].apply(lambda x: x[1] if type(x) == list else x)
wdf['Метро'] = wdf['Метро'].apply(lambda x: x+' Мира' if x == "Проспект" else x)
wdf['Метро'].value_counts()
# Out:
# Метро
# 0                1315
# Проспект Мира     644
# Улица             409
# Селигерская       393
# Щелковская        313
#                  ...
# Нахабино            1
# Театральная         1
# Зенит               1
# Яхромская           1
# Волковская          1
# Name: count, Length: 309, dtype: int64

# %% [markdown]
# ### Колонка: Площадь, м2.
# Задача: оставить только первое значение = общая площадь, последнее значение = площадь кухни

# %%
wdf['Площадь, м2'] = wdf['Площадь, м2'].apply(lambda x: x.split('/') if type(x) == str else x)
wdf['Площадь, м2'] = wdf['Площадь, м2'].apply(lambda x: x[:] if len(x) == 2 else [x[0],x[-1]])
wdf['Площадь, м2'].value_counts()
# Out:
# Площадь, м2
# [40.0, 10.0]     371
# [45.0, 6.0]      344
# [38.0, 8.0]      216
# [38.0, 10.0]     198
# [40.0, 9.0]      193
#                 ...
# [330.0, 20.0]      1
# [64.7, 6.0]        1
# [67.3, 16.0]       1
# [63.8, 5.0]        1
# [90.0, 15.5]       1
# Name: count, Length: 5372, dtype: int64

# %% [markdown]
# ### Колонка: Дом.
# Задача: привести к списку вида [этаж, количество этажей, тип строения]

# %%
# Разделим по запятой
wdf['Дом'] = wdf['Дом'].apply(lambda x: x.split() if type(x) == str else [x])
# Уберем запятую в первом значении каждого списка
wdf['Дом'] = wdf['Дом'].apply(lambda x: [x[0].replace(',',''), x[1]] if len(x) >1 and type(x[0]) == str else x)
# Приведем данные к виду [x/x, text]
wdf['Дом'] = wdf['Дом'].apply(lambda x: [x[0], 0] if len(x) == 1 else x)
# Привед данные к виду [этаж, количество этажей, тип строения]
wdf['Дом'] = wdf['Дом'].apply(lambda x: [*x[0].split('/'), x[1]])
# Приведем данные этажа и количества этажей к числовому типу
wdf['Дом'] = wdf['Дом'].apply(lambda x: [int(x[0]), int(x[1]), x[2]])

# %% [markdown]
# ### Колонка: Парковка.

# %%
# Данные по парковке чистые, не требуют преобразования
wdf['Парковка'].value_counts()
# Out:
# Парковка
# 0                 13417
# наземная           6043
# подземная          2772
# открытая           1017
# многоуровневая      118
# на крыше              1
# Name: count, dtype: int64

# %% [markdown]
# ### Колонка: Ремонт.

# %%
# Данные по ремонту чистые, не требуют преобразования
wdf['Ремонт'].value_counts()
# Out:
# Ремонт
# Косметический    8499
# Евроремонт       8470
# Дизайнерский     3474
# 0                2755
# Без ремонта       170
# Name: count, dtype: int64

# %% [markdown]
# ### Колонка: Балкон.
# Задача: Привести данные к виду [num1 , num2], где num1 = Балкон, num2 = Лоджия

# %%
# Сплит данных по запятой
wdf['Балкон'] = wdf['Балкон'].apply(lambda x: x.split(', ') if type(x) == str else [x, x])
# Приведем данные к виду [num1, num2]
wdf['Балкон'] = wdf['Балкон'].apply(lambda x: [x[0], 0] if len(x) == 1 else x)
# Вытащим числовое значение в данных по балконам и приведем к числовому типу
wdf['Балкон'] = wdf['Балкон'].apply(lambda x: [int(x[0][-2]), x[1]] if type(x[0]) == str else x)
# Вытащим числовое значение в данных по лоджиям и приведем к числовому типу
wdf['Балкон'] = wdf['Балкон'].apply(lambda x: [x[0], int(x[1][-2])] if type(x[1]) == str else x)
wdf['Балкон'].value_counts()
# Out:
# Балкон
# [1, 0]    13435
# [0, 0]     7978
# [2, 0]     1042
# [1, 1]      716
# [3, 0]      100
# [2, 2]       25
# [1, 2]       24
# [2, 1]       20
# [4, 0]       11
# [3, 1]        5
# [1, 3]        5
# [2, 3]        3
# [1, 4]        2
# [3, 3]        1
# [4, 4]        1
# Name: count, dtype: int64

# %% [markdown]
# ### Колонка: Окна

# %%
# Данные по окнам чистые, не требуют обработки
wdf['Окна'].value_counts()
# Out:
# Окна
# Во двор            10870
# 0                   6613
# На улицу и двор     3295
# На улицу            2590
# Name: count, dtype: int64

# %% [markdown]
# ### Колонка: Санузел.
# Задача: Привести данные к виду [num1 , num2], где num1 = Совмещенный, num2 = Раздельный

# %%
# Сплит данных по запятой
wdf['Санузел'] = wdf['Санузел'].apply(lambda x: x.split(', ') if type(x) == str else [x, x])
# Приведем данные к виду [num1, num2]
wdf['Санузел'] = wdf['Санузел'].apply(lambda x: [x[0], 0] if len(x) == 1 else x)
# Вытащим числовое значение в данных по балконам и приведем к числовому типу
wdf['Санузел'] = wdf['Санузел'].apply(lambda x: [int(x[0][-2]), x[1]] if type(x[0]) == str else x)
# Вытащим числовое значение в данных по лоджиям и приведем к числовому типу
wdf['Санузел'] = wdf['Санузел'].apply(lambda x: [x[0], int(x[1][-2])] if type(x[1]) == str else x)
wdf['Санузел'].value_counts()
# Out:
# Санузел
# [1, 0]    17236
# [0, 0]     2672
# [2, 0]     1971
# [1, 1]      812
# [3, 0]      293
# [2, 1]      188
# [4, 0]       92
# [1, 2]       30
# [3, 1]       27
# [2, 2]       25
# [3, 3]        6
# [4, 1]        6
# [4, 2]        4
# [1, 3]        2
# [2, 3]        2
# [2, 4]        1
# [3, 2]        1
# Name: count, dtype: int64

# %% [markdown]
# ### Колонка: Можно с детьми/животными.

# %%
# Данные по лояльности к существам с потенциальным риском нанесения материального ущерба чистые, не требуют обработки
wdf['Можно с детьми/животными'].value_counts()
# Out:
# Можно с детьми/животными
# Можно с детьми                       10134
# Можно с детьми, Можно с животными     6899
# 0                                     6096
# Можно с животными                      239
# Name: count, dtype: int64

# %% [markdown]
# ### Колонка: Высота потолков, м.
# Задача: Убрать выбросы

# %%
# Определим среднее значение высоты потолка
wdf[wdf['Высота потолков, м'].apply(lambda x: 2 < x < 4)]['Высота потолков, м'].mean()
# Получили значение 2.7
# Заменим выбросы на среднее значение высоты потолка
wdf['Высота потолков, м'] = wdf['Высота потолков, м'].apply(lambda x: 2.7 if x > 10 else x)
# Заменим нули на среднее значение потолка
wdf['Высота потолков, м'] = wdf['Высота потолков, м'].apply(lambda x: 2.7 if x == 0 else x)
wdf['Высота потолков, м'].value_counts()
# Out:
# Высота потолков, м
# 2.70    13220
# 2.64     4467
# 3.00     1322
# 2.48      676
# 3.20      617
#         ...
# 3.07        1
# 4.15        1
# 4.05        1
# 2.52        1
# 3.02        1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# ### Колонка: Лифт.
# Задача: Убрать выбросы

# %%
# Сплит данных по запятой
wdf['Лифт'] = wdf['Лифт'].apply(lambda x: x.split(', ') if type(x) == str else [x, x])
# Приведем данные к виду [num1, num2]
wdf['Лифт'] = wdf['Лифт'].apply(lambda x: [x[0], 0] if len(x) == 1 else x)
# Вытащим числовое значение в данных по балконам и приведем к числовому типу
wdf['Лифт'] = wdf['Лифт'].apply(lambda x: [int(x[0][-2]), x[1]] if type(x[0]) == str else x)
# Вытащим числовое значение в данных по лоджиям и приведем к числовому типу
wdf['Лифт'] = wdf['Лифт'].apply(lambda x: [x[0], int(x[1][-2])] if type(x[1]) == str else x)
wdf['Лифт'].value_counts()
# Out:
# Лифт
# [1, 0]    6006
# [0, 0]    5504
# [2, 0]    4346
# [1, 1]    3962
# [2, 1]    1224
# [2, 2]     654
# [3, 0]     651
# [4, 0]     371
# [3, 1]     187
# [1, 2]     186
# [4, 2]      65
# [4, 1]      64
# [3, 3]      45
# [3, 2]      44
# [4, 4]      28
# [4, 3]       7
# [6, 0]       7
# [1, 3]       6
# [2, 3]       3
# [5, 1]       1
# [8, 8]       1
# [7, 0]       1
# [1, 4]       1
# [5, 3]       1
# [2, 4]       1
# [8, 0]       1
# [5, 0]       1
# Name: count, dtype: int64

# %% [markdown]
# ### Колонка: Мусоропровод.

# %%
# Данные по мусоропроводам чистые, не требуют обработки
wdf['Мусоропровод'].value_counts()
# Out:
# Мусоропровод
# Да     10897
# 0      10522
# Нет     1949
# Name: count, dtype: int64

# %% [markdown]
# ## Финал.
# ### Вид датафрейма с обработанными данными

# %%
wdf.head(3)
# Описание изменений. 
# Note: колонки без изменений помечены знакосочетанием -/-
# Column: Unnamed: 0. -/-
# Column: ID объявления. -/-
# Column: Количество комнат. Приведено к типу int()
# Column: Метро. Приведено к виду "Название метро"
# Column: Площадь, м2. Приведено к виду ['Общая площадь', 'Площадь кухни']
# Column: Дом. Приведено к виду ['Этаж', 'Количество этажей', 'Тип строения']
# Column: Парковка. -/-
# Column: Ремонт. -/-
# Column: Балкон. Приведено к виду ['Количество балконов', 'Количество лоджий']
# Column: Окна. -/-
# Column: Санузел. Приведено к виду ['Совмещенный', 'Раздельный']
# Column: Можно с детьми/животными. -/-
# Column: Высота потолков, м. Убраны выбросы
# Column: Лифт. Приведено к виду ['Пассажирский', 'Грузовой']
# Column: Мусоропровод. -/-
# Out:
#    Unnamed: 0  ID объявления  Количество комнат       Метро    Площадь, м2  \
# 0           0      271271157                  4  Смоленская  [200.0, 20.0]
# 1           1      271634126                  4  Смоленская  [198.0, 18.0]
# 2           2      271173086                  4  Смоленская   [200.0, 4.0]
#
#                             Дом   Парковка  \
# 0           [5, 16, Монолитный]  подземная
# 1  [5, 16, Монолитно-кирпичный]  подземная
# 2                    [5, 16, 0]  подземная
#
#                                                 Цена        Ремонт  Балкон  \
# 0  500000.0 руб./ За месяц, Залог - 500000 руб., ...  Дизайнерский  [0, 0]
# 1  500000.0 руб./ За месяц, Залог - 500000 руб., ...  Дизайнерский  [0, 0]
# 2  500000.0 руб./ За месяц, Залог - 500000 руб., ...    Евроремонт  [0, 0]
#
#               Окна Санузел           Можно с детьми/животными  \
# 0                0  [0, 0]  Можно с детьми, Можно с животными
# 1  На улицу и двор  [2, 1]                     Можно с детьми
# 2  На улицу и двор  [3, 0]                     Можно с детьми
#
#    Высота потолков, м    Лифт Мусоропровод
# 0                 3.0  [4, 1]           Да
# 1                 3.5  [1, 1]          Нет
# 2                 3.2  [1, 0]            0

# %% [markdown]
# Формирование финального датафрейма, удобного для отображения графической аналитики. \
# Колонки со значениями типа list() разбиты на дополнительные колонки

# %%
#Обработка колонки Цены. 
fdf = pd.DataFrame() # fdf = final data frame
fdf['Unnamed: 0'] = wdf['Unnamed: 0']
fdf['ID объявления'] = wdf['ID объявления']
fdf['Количество комнат'] = wdf['Количество комнат']
fdf['Метро'] = wdf['Метро']
fdf['Общая площадь, м2'] = wdf['Площадь, м2'].apply(lambda x: x[0])
fdf['Площадь кухни, м2'] = wdf['Площадь, м2'].apply(lambda x: x[1])
fdf['Этаж'] = wdf['Дом'].apply(lambda x: x[0])
fdf['Этажей в доме'] = wdf['Дом'].apply(lambda x: x[1])
fdf['Тип строения'] = wdf['Дом'].apply(lambda x: x[2])
fdf['Парковка'] = wdf['Парковка']
# Вставить ! данные по ценам !
fdf['Ремонт'] = wdf['Ремонт']
fdf['Балкон'] = wdf['Балкон'].apply(lambda x: x[0])
fdf['Лоджия'] = wdf['Балкон'].apply(lambda x: x[1])
fdf['Окна'] = wdf['Окна']
fdf['Санузел раздельный'] = wdf['Санузел'].apply(lambda x: x[0])
fdf['Санузел совмещенный'] = wdf['Санузел'].apply(lambda x: x[1])
fdf['Можно с детьми/животными'] = wdf['Можно с детьми/животными']
fdf['Высота потолков, м'] = wdf['Высота потолков, м']
fdf['Лифты пасс.'] = wdf['Лифт'].apply(lambda x: x[0])
fdf['Лифты груз.'] = wdf['Лифт'].apply(lambda x: x[1])
fdf['Мусоропровод'] = wdf['Мусоропровод']

fdf
# Out:
#        Unnamed: 0  ID объявления  Количество комнат       Метро  \
# 0               0      271271157                  4  Смоленская
# 1               1      271634126                  4  Смоленская
# 2               2      271173086                  4  Смоленская
# 3               3      272197456                  4  Смоленская
# 4               4      273614615                  2   Арбатская
# ...           ...            ...                ...         ...
# 23363       23363      215565511                  0    Говорово
# 23364       23364      274654844                  1    Солнцево
# 23365       23365      268679909                  2    Солнцево
# 23366       23366      274807525                  2    Солнцево
# 23367       23367      274672243                  2    Говорово
#
#       Общая площадь, м2 Площадь кухни, м2  Этаж  Этажей в доме  \
# 0                 200.0              20.0     5             16
# 1                 198.0              18.0     5             16
# 2                 200.0               4.0     5             16
# 3                 170.0              17.0     5              6
# 4                  58.0               5.0    12             26
# ...                 ...               ...   ...            ...
# 23363              35.0               8.0    10             14
# 23364              38.7              11.0     5             18
# 23365              43.1              43.1     5              5
# 23366              52.5              10.0     8             23
# 23367              90.0              15.5     6             23
#
#               Тип строения   Парковка         Ремонт  Балкон  Лоджия  \
# 0               Монолитный  подземная   Дизайнерский       0       0
# 1      Монолитно-кирпичный  подземная   Дизайнерский       0       0
# 2                        0  подземная     Евроремонт       0       0
# 3                        0  подземная     Евроремонт       0       0
# 4                Панельный          0     Евроремонт       0       0
# ...                    ...        ...            ...     ...     ...
# 23363                    0          0     Евроремонт       1       0
# 23364           Монолитный          0     Евроремонт       1       0
# 23365            Кирпичный          0   Дизайнерский       1       0
# 23366           Монолитный   наземная     Евроремонт       1       0
# 23367            Панельный          0  Косметический       1       0
#
#                   Окна  Санузел раздельный  Санузел совмещенный  \
# 0                    0                   0                    0
# 1      На улицу и двор                   2                    1
# 2      На улицу и двор                   3                    0
# 3      На улицу и двор                   3                    0
# 4      На улицу и двор                   2                    0
# ...                ...                 ...                  ...
# 23363                0                   1                    0
# 23364          Во двор                   1                    0
# 23365  На улицу и двор                   1                    0
# 23366          Во двор                   1                    1
# 23367          Во двор                   1                    0
#
#                 Можно с детьми/животными  Высота потолков, м  Лифты пасс.  \
# 0      Можно с детьми, Можно с животными                3.00            4
# 1                         Можно с детьми                3.50            1
# 2                         Можно с детьми                3.20            1
# 3                      Можно с животными                3.20            1
# 4                                      0                3.90            1
# ...                                  ...                 ...          ...
# 23363                                  0                2.70            1
# 23364                                  0                2.70            1
# 23365                     Можно с детьми                2.70            0
# 23366                                  0                2.65            3
# 23367  Можно с детьми, Можно с животными                2.70            3
#
#        Лифты груз. Мусоропровод
# 0                1           Да
# 1                1          Нет
# 2                0            0
# 3                0            0
# 4                1           Да
# ...            ...          ...
# 23363            1            0
# 23364            1            0
# 23365            0            0
# 23366            0           Да
# 23367            0           Да
#
# [23368 rows x 21 columns]

# %%
#Преобразуем колонку Цены в списки
counts = wdf.copy()
counts['Цена'] = wdf['Цена'].apply(lambda x: x.split(','))

#Теперь функция для обработки каждого элемента (i) в списке Series (х)

def price(x):
    communal = []      #коммуналка
    prepayment = []    #предоплата
    bail = []          #залог
    rent = []          #квартплата
    rental = []        #срок
    
    for i in x:   #берем i-ый элемент списка Цены (х)

        
        if 'За месяц' in i:                    #здесь две проверки на наличие валют и перевод в рубли. так же ищем в 
            if '$' in i:                       # строке только числовые данные и сохраняем их в Квартплату
                numbers = (re.findall(r'\d+\.\d+|\d+', i))[0]
                rent = float(numbers[0]) * 97
            elif '€' in i:
                numbers = (re.findall(r'\d+\.\d+|\d+', i))[0]
                rent = float(numbers[0]) * 106
            else:
                numbers = re.findall(r'\d+\.\d+|\d+', i) 
                rent = float(numbers[0])


        
        elif 'Залог' in i or 'залог' in i:      #здесь две проверки на наличие валют и перевод в рубли. так же ищем в 
            if '$' in i:                        #строке только числовые данные и сохраняем их в Залог
                numbers = (re.findall(r'\b\d+\b', i))[0]
                bail = int(numbers[0]) * 97
            elif '€' in i:
                numbers = (re.findall(r'\b\d+\b', i))[0]
                bail = int(numbers[0]) * 106
            else:
                numbers = re.findall(r'\b\d+\b', i) 
                bail = int(numbers[0])

        
        elif 'комм' in i or 'Комм' in i:       #здесь две проверки на необходисомть платить за комуналку и сами цены 
            if 'включены' in i:
                communal = 0
            else:
                numbers = (re.findall(r'\b\d+\b', i))[0]
                communal= float(numbers)                
                
        
        elif 'Срок' in i or 'срок' in i:      #здесь ищем и сохраняем срок аренды
            rental.append(i)

        
        elif 'Предоплата' in i:               #здесь ищем и сохраняем на какое количество месяцев необходимо внести Предоплату
            numbers = re.findall(r'\d+', i)
            prepayment = int(numbers[0])

         
    return pd.Series({
        'Квартплата': rent if rent else 0,
        'Залог': bail if bail else 0,
        'комм': communal if communal is not None else None,
        'Срок': ', '.join(rental) if rental else 0,
        'Предоплата': prepayment if prepayment else 0
    })
        

fdf = pd.DataFrame() # fdf = final data frame
#fdf['Unnamed: 0'] = wdf['Unnamed: 0'] закомментила чтоб не двоилось
fdf['ID объявления'] = wdf['ID объявления']
fdf['Количество комнат'] = wdf['Количество комнат']
fdf['Метро'] = wdf['Метро']
fdf['Общая площадь, м2'] = wdf['Площадь, м2'].apply(lambda x: x[0])
fdf['Площадь кухни, м2'] = wdf['Площадь, м2'].apply(lambda x: x[1])
fdf['Этаж'] = wdf['Дом'].apply(lambda x: x[0])
fdf['Этажей в доме'] = wdf['Дом'].apply(lambda x: x[1])
fdf['Тип строения'] = wdf['Дом'].apply(lambda x: x[2])
fdf['Парковка'] = wdf['Парковка']
# Блок кода со вставкой числовых значений исходной колонки Цена
#Теперь создаем новые колонки, данные для которых берем из Цена
fdf[['Квартплата', 'Залог', 'комм', 'Срок', 'Предоплата']] = counts['Цена'].apply(price)

#Теперь делаю 0 там где коммуналку включена в стоимость аренды, а остальные пустые значения заменяю средними (но при посчете среднего не учитываю 0).
fdf['комм'] = fdf['комм'].apply(lambda x: np.nan if x == [] else x)
fdf['комм'].fillna(fdf['комм'][fdf['комм'] != 0].mean(), inplace=True)

#Немного округляю среднее
fdf['комм'] = fdf['комм'].round(3)

fdf['Ремонт'] = wdf['Ремонт']
fdf['Балкон'] = wdf['Балкон'].apply(lambda x: x[0])
fdf['Лоджия'] = wdf['Балкон'].apply(lambda x: x[1])
fdf['Окна'] = wdf['Окна']
fdf['Санузел раздельный'] = wdf['Санузел'].apply(lambda x: x[0])
fdf['Санузел совмещенный'] = wdf['Санузел'].apply(lambda x: x[1])
fdf['Можно с детьми/животными'] = wdf['Можно с детьми/животными']
fdf['Высота потолков, м'] = wdf['Высота потолков, м']
fdf['Лифты пасс.'] = wdf['Лифт'].apply(lambda x: x[0])
fdf['Лифты груз.'] = wdf['Лифт'].apply(lambda x: x[1])
fdf['Мусоропровод'] = wdf['Мусоропровод']
# Out:
# /var/folders/kv/qln84_yj3590ygc7bsrfymzm0000gn/T/ipykernel_31338/692967088.py:85: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fdf['комм'].fillna(fdf['комм'][fdf['комм'] != 0].mean(), inplace=True)

# %% [markdown]
# ## EDA_basic датафрейм.
# На базе обработанного к текущему моменту датафрейма строятся необходимые для EDA анализа графики

# %%
fdf.to_csv('report.csv', index=False)

# %%
fdf # final data frame
# Out:
#        ID объявления  Количество комнат       Метро Общая площадь, м2  \
# 0          271271157                  4  Смоленская             200.0
# 1          271634126                  4  Смоленская             198.0
# 2          271173086                  4  Смоленская             200.0
# 3          272197456                  4  Смоленская             170.0
# 4          273614615                  2   Арбатская              58.0
# ...              ...                ...         ...               ...
# 23363      215565511                  0    Говорово              35.0
# 23364      274654844                  1    Солнцево              38.7
# 23365      268679909                  2    Солнцево              43.1
# 23366      274807525                  2    Солнцево              52.5
# 23367      274672243                  2    Говорово              90.0
#
#       Площадь кухни, м2  Этаж  Этажей в доме         Тип строения   Парковка  \
# 0                  20.0     5             16           Монолитный  подземная
# 1                  18.0     5             16  Монолитно-кирпичный  подземная
# 2                   4.0     5             16                    0  подземная
# 3                  17.0     5              6                    0  подземная
# 4                   5.0    12             26            Панельный          0
# ...                 ...   ...            ...                  ...        ...
# 23363               8.0    10             14                    0          0
# 23364              11.0     5             18           Монолитный          0
# 23365              43.1     5              5            Кирпичный          0
# 23366              10.0     8             23           Монолитный   наземная
# 23367              15.5     6             23            Панельный          0
#
#        Квартплата   Залог      комм                       Срок  Предоплата  \
# 0        500000.0  500000     0.000   Срок аренды - Длительный           1
# 1        500000.0  500000     0.000   Срок аренды - Длительный           1
# 2        500000.0  500000  5160.697   Срок аренды - Длительный           1
# 3        400000.0  400000  5160.697   Срок аренды - Длительный           1
# 4        225000.0  225000     0.000   Срок аренды - Длительный           1
# ...           ...     ...       ...                        ...         ...
# 23363     42000.0   42000     0.000   Срок аренды - Длительный           1
# 23364     45000.0   45000     0.000   Срок аренды - Длительный           1
# 23365     50000.0   50000     0.000   Срок аренды - Длительный           1
# 23366     55000.0   50000     0.000   Срок аренды - Длительный           2
# 23367     57000.0   60000     0.000   Срок аренды - Длительный           1
#
#               Ремонт  Балкон  Лоджия             Окна  Санузел раздельный  \
# 0       Дизайнерский       0       0                0                   0
# 1       Дизайнерский       0       0  На улицу и двор                   2
# 2         Евроремонт       0       0  На улицу и двор                   3
# 3         Евроремонт       0       0  На улицу и двор                   3
# 4         Евроремонт       0       0  На улицу и двор                   2
# ...              ...     ...     ...              ...                 ...
# 23363     Евроремонт       1       0                0                   1
# 23364     Евроремонт       1       0          Во двор                   1
# 23365   Дизайнерский       1       0  На улицу и двор                   1
# 23366     Евроремонт       1       0          Во двор                   1
# 23367  Косметический       1       0          Во двор                   1
#
#        Санузел совмещенный           Можно с детьми/животными  \
# 0                        0  Можно с детьми, Можно с животными
# 1                        1                     Можно с детьми
# 2                        0                     Можно с детьми
# 3                        0                  Можно с животными
# 4                        0                                  0
# ...                    ...                                ...
# 23363                    0                                  0
# 23364                    0                                  0
# 23365                    0                     Можно с детьми
# 23366                    1                                  0
# 23367                    0  Можно с детьми, Можно с животными
#
#        Высота потолков, м  Лифты пасс.  Лифты груз. Мусоропровод
# 0                    3.00            4            1           Да
# 1                    3.50            1            1          Нет
# 2                    3.20            1            0            0
# 3                    3.20            1            0            0
# 4                    3.90            1            1           Да
# ...                   ...          ...          ...          ...
# 23363                2.70            1            1            0
# 23364                2.70            1            1            0
# 23365                2.70            0            0            0
# 23366                2.65            3            0           Да
# 23367                2.70            3            0           Да
#
# [23368 rows x 25 columns]

# %% [markdown]
# ## Графики
# Строим графики на основе полученных данных

# %% [markdown]
# Для построения графика нам надо отфильтровать наш датасет, убрав из него нулевые значения

# %%
fdf_filter = fdf[
    (fdf['Квартплата'] > 0) &
    (fdf['комм'] > 0) &
    (fdf['Тип строения'] != 0) &
    (fdf['Метро'] != 0) & 
    (fdf['Парковка'] != 0) & 
    (fdf['Ремонт'] != 0) &
    (fdf['Окна'] != 0) &
    (fdf['Можно с детьми/животными'] != 0) &
    (fdf['Мусоропровод'] != 0) 
]

# %%
fdf_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 173 entries, 896 to 22815
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID объявления             173 non-null    int64
#  1   Количество комнат         173 non-null    int64
#  2   Метро                     173 non-null    object
#  3   Общая площадь, м2         173 non-null    object
#  4   Площадь кухни, м2         173 non-null    object
#  5   Этаж                      173 non-null    int64
#  6   Этажей в доме             173 non-null    int64
#  7   Тип строения              173 non-null    object
#  8   Парковка                  173 non-null    object
#  9   Квартплата                173 non-null    float64
#  10  Залог                     173 non-null    int64
#  11  комм                      173 non-null    float64
#  12  Срок                      173 non-null    object
#  13  Предоплата                173 non-null    int64
#  14  Ремонт                    173 non-null    object
#  15  Балкон                    173 non-null    int64
#  16  Лоджия                    173 non-null    int64
#  17  Окна                      173 non-null    object
#  18  Санузел раздельный        173 non-null    int64
#  19  Санузел совмещенный       173 non-null    int64
#  20  Можно с детьми/животными  173 non-null    object
#  21  Высота потолков, м        173 non-null    float64
#  22  Лифты пасс.               173 non-null    int64
#  23  Лифты груз.               173 non-null    int64
#  24  Мусоропровод              173 non-null    object
# dtypes: float64(3), int64(12), object(10)
# memory usage: 35.1+ KB

# %% [markdown]
# ### 1. Посмотрим как зависит Квартплата от коммуналки и типа строения

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=fdf_filter, x='Квартплата', y='комм', hue='Тип строения', palette='deep')
# Настройка графика
plt.title('График рассеяния: Квартплата, Коммуналка и тип строения')
plt.xlabel('Стоимость')
plt.ylabel('Коммуналка')
plt.legend(title='Тип строения');
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Метро. Распределение.
# Мысли:
# 1. Нужна только Москва. Если занчение ноль -- нет метро, квартира находится не в Москве2
# 2. Показать как квартиры распределены относительно `метро`

# %%
sns.displot(fdf,)
